# %%
import pandas as pd
import numpy as np

# %%
import requests

# %%
url = "https://jaredlander.com/data/PizzaPollData.php"
response = requests.get (url).json()

# %%
response
# Out:
# [{'polla_qid': 2,
#   'Answer': 'Excellent',
#   'Votes': 0,
#   'pollq_id': 2,
#   'Question': 'How was Pizza Mercato?',
#   'Place': 'Pizza Mercato',
#   'Time': 1344361527,
#   'TotalVotes': 13,
#   'Percent': 0},
#  {'polla_qid': 2,
#   'Answer': 'Good',
#   'Votes': 6,
#   'pollq_id': 2,
#   'Question': 'How was Pizza Mercato?',
#   'Place': 'Pizza Mercato',
#   'Time': 1344361527,
#   'TotalVotes': 13,
#   'Percent': 0.4615},
#  {'polla_qid': 2,
#   'Answer': 'Average',
#   'Votes': 4,
#   'pollq_id': 2,
#   'Question': 'How was Pizza Mercato?',
#   'Place': 'Pizza Mercato',
#   'Time': 1344361527,
#   'TotalVotes': 13,
#   'Percent': 0.3077},
#  {'polla_qid': 2,
#   'Answer': 'Poor',
#   'Votes': 1,
#   'pollq_id': 2,
#   'Question': 'How was Pizza Mercato?',
#   'Place': 'Pizza Mercato',
#   'Time': 1344361527,
#   'TotalVotes': 13,
#   'Percent': 0.0769},
#  {'polla_qid': 2,
#   'Answer': 'Never Again',
#   'Votes': 2,
#   'pollq_id': 2,
# ...

# %%
Jared_Pizza_df = pd.DataFrame(response)
Jared_Pizza_df
# Out:
#      polla_qid       Answer  Votes  pollq_id                     Question  \
# 0            2    Excellent      0         2       How was Pizza Mercato?
# 1            2         Good      6         2       How was Pizza Mercato?
# 2            2      Average      4         2       How was Pizza Mercato?
# 3            2         Poor      1         2       How was Pizza Mercato?
# 4            2  Never Again      2         2       How was Pizza Mercato?
# ..         ...          ...    ...       ...                          ...
# 405         85    Excellent      1        85  How was Sofia Pizza Shoppe?
# 406         85         Good      3        85  How was Sofia Pizza Shoppe?
# 407         85      Average     10        85  How was Sofia Pizza Shoppe?
# 408         85         Poor      1        85  How was Sofia Pizza Shoppe?
# 409         85  Never Again      1        85  How was Sofia Pizza Shoppe?
#
#                   Place        Time  TotalVotes  Percent
# ...

# %%
Jared_Pizza_df.dropna()
Jared_Pizza_df
# Out:
#      polla_qid       Answer  Votes  pollq_id                     Question  \
# 0            2    Excellent      0         2       How was Pizza Mercato?
# 1            2         Good      6         2       How was Pizza Mercato?
# 2            2      Average      4         2       How was Pizza Mercato?
# 3            2         Poor      1         2       How was Pizza Mercato?
# 4            2  Never Again      2         2       How was Pizza Mercato?
# ..         ...          ...    ...       ...                          ...
# 405         85    Excellent      1        85  How was Sofia Pizza Shoppe?
# 406         85         Good      3        85  How was Sofia Pizza Shoppe?
# 407         85      Average     10        85  How was Sofia Pizza Shoppe?
# 408         85         Poor      1        85  How was Sofia Pizza Shoppe?
# 409         85  Never Again      1        85  How was Sofia Pizza Shoppe?
#
#                   Place        Time  TotalVotes  Percent
# ...

# %%
Jared_Pizza_df.drop_duplicates()
Jared_Pizza_df
# Out:
#      polla_qid       Answer  Votes  pollq_id                     Question  \
# 0            2    Excellent      0         2       How was Pizza Mercato?
# 1            2         Good      6         2       How was Pizza Mercato?
# 2            2      Average      4         2       How was Pizza Mercato?
# 3            2         Poor      1         2       How was Pizza Mercato?
# 4            2  Never Again      2         2       How was Pizza Mercato?
# ..         ...          ...    ...       ...                          ...
# 405         85    Excellent      1        85  How was Sofia Pizza Shoppe?
# 406         85         Good      3        85  How was Sofia Pizza Shoppe?
# 407         85      Average     10        85  How was Sofia Pizza Shoppe?
# 408         85         Poor      1        85  How was Sofia Pizza Shoppe?
# 409         85  Never Again      1        85  How was Sofia Pizza Shoppe?
#
#                   Place        Time  TotalVotes  Percent
# ...

# %%
Jared_Pizza_df.drop(columns)

# %%
Data_Finiti_pizza_df = pd.read_csv("DataFiniti_Pizza_Restaurants_and_pizza_they_sell_may19.csv")
Data_Finiti_pizza_df
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AVz3Y-7h3D1zeR_xDAqm  2017-06-30T05:05:40Z  2019-05-01T15:43:09Z
# 1     AVweGPFF_7pvs4fzAAzQ  2016-04-02T04:02:49Z  2019-05-01T15:27:50Z
# 2     AVwdRGa9_7pvs4fz4E3K  2016-03-03T18:39:49Z  2019-05-01T12:52:25Z
# 3     AVwdX4psIN2L1WUfvJB1  2016-03-29T05:08:59Z  2019-05-01T12:52:20Z
# 4     AVwdaeTtkufWRAb55pSH  2016-03-31T02:34:04Z  2019-05-01T12:50:45Z
# ...                    ...                   ...                   ...
# 9995  AVwdKXFYByjofQCxmIyZ  2016-03-21T00:12:46Z  2018-01-08T10:25:27Z
# 9996  AVwdKXFYByjofQCxmIyZ  2016-03-21T00:12:46Z  2018-01-08T10:25:27Z
# 9997  AVz6kzsQFcQ3k02bDhwQ  2017-06-30T19:56:11Z  2018-01-07T10:51:29Z
# 9998  AVz6kzsQFcQ3k02bDhwQ  2017-06-30T19:56:11Z  2018-01-07T10:51:29Z
# 9999  AVwdG9zTkufWRAb52Y2A  2015-10-23T01:57:27Z  2018-01-04T17:57:59Z
#
#                     address  \
# 0          4203 E Kiehl Ave
# 1         25 E Camelback Rd
# ...

# %%
Data_Finiti_pizza_df.dropna()
Data_Finiti_pizza_df
